# %% [markdown]
# <a href="https://colab.research.google.com/github/eelcofolkertsma/BIX-samples/blob/main/Receive-samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pika
import pika
from google.colab import files
import string
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.0/165.0 kB 4.1 MB/s eta 0:00:00
# ...

# %%
site='bcs-pilot.iata.org'
user='iata-pilot'
password='Bcsp1l0t$'
virtual_host='/iata-pilot'
queue='iata-output-1755'
exchange='iata-ex'

url = 'amqps://' + user +':'+ password +'@' +site + virtual_host #amqp://username:password@hostname:port/vhost_name
params = pika.URLParameters(url)
params = pika.URLParameters(url)
connection = pika.BlockingConnection(params)
channel = connection.channel() # start a channel
#channel.queue_declare(queue=queue) # Declare a queue
def callback(ch, method, properties, body):
  print(" [x] Received " + str(body))

channel.basic_consume(queue,
                      callback,
                      auto_ack=True)

print(' [*] Waiting for messages:')
channel.start_consuming()
connection.close()
# Out:
#  [*] Waiting for messages:
# ...

# %%
import xml.etree.ElementTree as ET
body=b'<?xml version="1.0" encoding="utf-8"?>\n<IATA_Baggage_BagRQ xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns="http://www.iata.org/IATA/2015/00/2025.4.1/IATA_Baggage_BagRQ">\n  <BagSegment>\n    <Bag>\n      <BagTag>\n        <IssuerCode>123</IssuerCode>\n        <SerialNumberID>456789</SerialNumberID>\n        <UsageCode>0</UsageCode>\n      </BagTag>\n      <Owner>\n        <GivenName>SIMON</GivenName>\n        <Role>\n          <Pax>\n            <Booking>\n              <BookingID>ABCDEF</BookingID>\n            </Booking>\n          </Pax>\n        </Role>\n        <Surname>KEINER</Surname>\n      </Owner>\n    </Bag>\n    <BaggageProcess>\n      <BaggageProcessCode>L</BaggageProcessCode>\n    </BaggageProcess>\n    <CarryingSegment>\n      <AircraftScheduledDepDateTime>2026-07-07T00:00:00</AircraftScheduledDepDateTime>\n      <ArrivalIATA_LocationCode>SIN</ArrivalIATA_LocationCode>\n      <CarrierDesigCode>XH</CarrierDesigCode>\n      <DepIATA_LocationCode>FMO</DepIATA_LocationCode>\n      <FlightNumberText>1234</FlightNumberText>\n    </CarryingSegment>\n    <ClassOfServiceCode>Y</ClassOfServiceCode>\n    <SegmentSecurityControls>\n      <AuthorityToLoadInd>true</AuthorityToLoadInd>\n      <BagTagStatusCode>A</BagTagStatusCode>\n      <PaxStatus>\n        <BoardingStatusCode>C</BoardingStatusCode>\n        <CheckInSeqNumber>100</CheckInSeqNumber>\n        <SeatID>7A</SeatID>\n        <SecurityProfileStatusInd>false</SecurityProfileStatusInd>\n      </PaxStatus>\n    </SegmentSecurityControls>\n  </BagSegment>\n</IATA_Baggage_BagRQ>'
body=b'''<?xml version="1.0" encoding="utf-8"?>
<IATA_Baggage_ULD_RS xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns="http://www.iata.org/IATA/2015/00/2025.4.1/IATA_Baggage_ULDRS">
  <ULD_Allocation>
    <BaggageProcess>
      <Agent>
        <Agency>
          <AgencyCode>LH</AgencyCode>
        </Agency>
        <AgentID>GHA</AgentID>
      </Agent>
      <BaggageEvent>
        <ActualDateTime>2011-04-01T09:45:00</ActualDateTime>
        <Facility>
          <BaggageFacilityType>
            <BaggageFacilityTypeCode>RM</BaggageFacilityTypeCode>
          </BaggageFacilityType>
          <Station>
            <IATA_LocationCode>FRA</IATA_LocationCode>
          </Station>
        </Facility>
        <Scanner>
          <ScannerID>HHT234</ScannerID>
        </Scanner>
      </BaggageEvent>
      <BaggageProcessCode>L</BaggageProcessCode>
      <BaggageSubProcessCode>Load</BaggageSubProcessCode>
      <BaggageSubSubProcessCode>Load</BaggageSubSubProcessCode>
      <DescText>Baggage Make Up Area</DescText>
    </BaggageProcess>
    <CarryingSegment>
      <AircraftScheduledDepDateTime>2026-04-11T00:00:00</AircraftScheduledDepDateTime>
      <ArrivalIATA_LocationCode>JFK</ArrivalIATA_LocationCode>
      <CarrierDesigCode>LH</CarrierDesigCode>
      <DepIATA_LocationCode>FRA</DepIATA_LocationCode>
      <FlightID_Date>2026-04-11</FlightID_Date>
      <FlightNumberText>0123</FlightNumberText>
    </CarryingSegment>
    <Delivery>
      <Facility>
        <BaggageFacilityType>
          <BaggageFacilityTypeCode>RM</BaggageFacilityTypeCode>
        </BaggageFacilityType>
        <FacilityID>V118</FacilityID>
        <Station>
          <IATA_LocationCode>FRA</IATA_LocationCode>
        </Station>
      </Facility>
    </Delivery>
    <InternalAirlineData>ACT/GT/U</InternalAirlineData>
    <InternalAirlineData>-CORR/5-9-10</InternalAirlineData>
    <ULD>
      <OwnerCode>LH</OwnerCode>
      <SerialNumberID>AKE12345LH</SerialNumberID>
    </ULD>
  </ULD_Allocation>
</IATA_Baggage_ULD_RS>'''

root = ET.fromstring(body)
print(root.findall("InternalAirlineData"))
# Out:
# []
